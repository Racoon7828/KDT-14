# %% [markdown]
# ### [ 히스토그램과 대비 제한 적응형 히스토그램 평탄화 : CLAHE] <hr>
# - 이미지의 조명에 따른 부분 밝기 차이가 큰 경우
# - 일정 크기의 블록(기: 8x8)으로 나눈 후 블록 단위 평탄화 진행 => 적응형 히스토그램 평탄화(AHE)
#     - 단점 : 고대비 문제를 해결하기위한 방식
# - => CLAHE
#     - 단점 : 최적의 파라미터 값 찾기

# %%
import numpy as np, cv2, matplotlib.pyplot as plt, koreanize_matplotlib, sys
sys.path.append(r'C:\Users\Win11Pro\Desktop\KDT-14\[7]_CVISION')
from cv_utils import printPlotImage

# %%
IMG_FILE = '../Data/images/yate.jpg'

# %%
gray = cv2.imread(IMG_FILE, cv2.IMREAD_GRAYSCALE)
img = cv2.imread(IMG_FILE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 gray = cv2.imread(IMG_FILE, cv2.IMREAD_GRAYSCALE)
#       2 img = cv2.imread(IMG_FILE)
#
# NameError: name 'IMG_FILE' is not defined
